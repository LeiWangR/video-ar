# %% [markdown]
# # Taylor videos on skeletons for action recognition

# %% [markdown]
# ## 1. Taylor videos on skeletons

# %%
import scipy
from scipy import io
import torch

# %%
def factorial(n):
    """
    Calculate factorial of each element in the input tensor using recursion.
    """
    # Base case: factorial of 0 is 1
    if n == 0:
        return torch.tensor(1)
    else:
        return n * factorial(n - 1)

# %%
def taylor_video(videoinput, terms, temporal_block):
    
    # assume stride = 1
    video = torch.from_numpy(scipy.io.loadmat(videoinput)['skeletonsequence'])
    
    J, C, T = video.shape
    
    if temporal_block - 3 < terms:
        print('The given temporal block length is not enough to compute terms defined.')
        
    else:
        Taylor = torch.zeros((J, C, T - temporal_block + 1))
        
        for i in range(T - temporal_block + 1):
            # index starts from 0
            video_clip = video[:, :, i:i+temporal_block]
            slice_tensor = video[:, :, i].unsqueeze(2)
            dummy_clip = slice_tensor.repeat(1, 1, temporal_block)
            
            delta_temp = video_clip - dummy_clip
            
            D_temp = torch.zeros(J, C, terms + 2)
            
            temp = video_clip
            
            for j in range(terms+2):
                diff = temp[:, :, 1:] - temp[:, :, :-1]
                D_temp[:, :, j] = diff[:, :, 0]
                temp = diff
            
            M = torch.zeros((J, C, temporal_block))
            
            for order in range(terms+1):
                M = M + (D_temp[:, :, order].unsqueeze(-1) / factorial(order)) * torch.pow(delta_temp, order)               
                
            taylor_frame = M.sum(2)

            Taylor[:, :, i] = taylor_frame
    
    return Taylor

# %%
sk = '/Users/leiwang/Desktop/skeleton/a05_s01_e01_skeleton3D.txtssq.mat'

taylorskeleton = taylor_video(sk, 1, 4)

# %%
skeleton = scipy.io.loadmat(sk)['skeletonsequence']
print(skeleton.shape)
# print(type(skeleton))

skeleton = torch.from_numpy(skeleton)
# Out:
# (20, 3, 44)

# %%
taylorskeleton.shape
# Out:
# torch.Size([20, 3, 41])

# %% [markdown]
# ## 2. Visualisation of original skeletons

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML, display

num_frames = skeleton.shape[2]
num_joints = skeleton.shape[0]  

# Example connections of bones
sk_config = [[12, 10, 8, 1, 2, 0, 7, 9, 11], [19, 2, 3, 6, 5, 14, 16, 18], [6, 4, 13, 15, 17]]

# Function to plot 2D skeleton frame with connections (showing x as horizontal, y as vertical)
def plot_skeleton_frame_2d(frame_data, sk_config, ax):
    ax.clear()
    ax.set_title("2D Skeleton Frame (Horizontal X, Vertical Y)")

    # Plot joints (x as horizontal, y as vertical)
    for i in range(num_joints):
        x = frame_data[i, 0]
        y = frame_data[i, 1]
        ax.scatter(x, y, color='r')  # Plot x and y
    
    # Plot connections
    for connections in sk_config:
        for i in range(len(connections) - 1):
            start_joint = connections[i]
            end_joint = connections[i + 1]
            ax.plot([frame_data[start_joint, 0], frame_data[end_joint, 0]],
                    [frame_data[start_joint, 1], frame_data[end_joint, 1]], color='b')  # Plot connections
    
    # Set aspect ratio
    ax.set_aspect('equal')  # Equal aspect ratio

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 8))

# Initialize the plot with the first frame
plot_skeleton_frame_2d(skeleton[:, :, 0], sk_config, ax)

# Function to update the plot for each frame
def update(frame):
    plot_skeleton_frame_2d(skeleton[:, :, frame], sk_config, ax)

# Create the animation
ani = FuncAnimation(fig, update, frames=num_frames, interval=100)  # Interval in milliseconds

# Disable xticks, yticks, xlabel, and ylabel
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('')
ax.set_ylabel('')

# Display the animation using HTML display
html_anim = HTML(ani.to_jshtml())
display(html_anim)

# Hide the ticks and axis labels
plt.close()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img898a4c7b2ceb4bd0bfdd63784e349991">
#   <div class="anim-controls">
#     <input id="_anim_slider898a4c7b2ceb4bd0bfdd63784e349991" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim898a4c7b2ceb4bd0bfdd63784e349991.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim898a4c7b2ceb4bd0bfdd63784e349991.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim898a4c7b2ceb4bd0bfdd63784e349991.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim898a4c7b2ceb4bd0bfdd63784e349991.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim898a4c7b2ceb4bd0bfdd63784e349991.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim898a4c7b2ceb4bd0bfdd63784e349991.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim898a4c7b2ceb4bd0bfdd63784e349991.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim898a4c7b2ceb4bd0bfdd63784e349991.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim898a4c7b2ceb4bd0bfdd63784e349991.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim898a4c7b2ceb4bd0bfdd63784e349991.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select898a4c7b2ceb4bd0bfdd63784e349991"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_898a4c7b2ceb4bd0bfdd63784e349991"
#              >
#       <label for="_anim_radio1_898a4c7b2ceb4bd0bfdd63784e349991">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_898a4c7b2ceb4bd0bfdd63784e349991"
#              checked>
#       <label for="_anim_radio2_898a4c7b2ceb4bd0bfdd63784e349991">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_898a4c7b2ceb4bd0bfdd63784e349991"
#              >
#       <label for="_anim_radio3_898a4c7b2ceb4bd0bfdd63784e349991">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img898a4c7b2ceb4bd0bfdd63784e349991";
#     var slider_id = "_anim_slider898a4c7b2ceb4bd0bfdd63784e349991";
#     var loop_select_id = "_anim_loop_select898a4c7b2ceb4bd0bfdd63784e349991";
#     var frames = new Array(44);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/MnkTPAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %% [markdown]
# ## 3. Visualisation of Taylor videos on original skeletons

# %%
num_taylor = taylorskeleton.shape[2]
num_frames = skeleton.shape[2]
num_joints = skeleton.shape[0]

# Example connections of bones
sk_config = [[12, 10, 8, 1, 2, 0, 7, 9, 11], [19, 2, 3, 6, 5, 14, 16, 18], [6, 4, 13, 15, 17]]

# Function to plot 2D skeleton frame with connections (showing x as horizontal, y as vertical)
def plot_skeleton_frame_2d(frame_data, taylor_data, sk_config, ax):
    ax.clear()
    ax.set_title("2D Skeleton Frame (Horizontal X, Vertical Y)")

    # Plot joints (x as horizontal, y as vertical)
    for i in range(num_joints):
        x = frame_data[i, 0]
        y = frame_data[i, 1]
        a = taylor_data[i, 0]
        b = taylor_data[i, 1]
        ss = int(5000 * (abs(a) + abs(b)) / 2)  # Adjust the scaling factor as needed
        ax.scatter(x, y, color='r', s=ss)  # Plot x and y

    # Plot connections
    for connections in sk_config:
        for i in range(len(connections) - 1):
            start_joint = connections[i]
            end_joint = connections[i + 1]
            ax.plot([frame_data[start_joint, 0], frame_data[end_joint, 0]],
                    [frame_data[start_joint, 1], frame_data[end_joint, 1]], color='b')  # Plot connections

    # Set aspect ratio
    ax.set_aspect('equal')  # Equal aspect ratio

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 8))

# Initialize the plot with the first frame
plot_skeleton_frame_2d(skeleton[:, :, 0], taylorskeleton[:, :, 0], sk_config, ax)

# Function to update the plot for each frame
def update(frame):
    plot_skeleton_frame_2d(skeleton[:, :, frame], taylorskeleton[:, :, frame], sk_config, ax)

# Create the animation
ani = FuncAnimation(fig, update, frames=num_taylor, interval=100)  # Interval in milliseconds

# Display the animation using HTML display
html_anim = HTML(ani.to_jshtml())
display(html_anim)

# Hide the ticks and axis labels
plt.close()  # Close the plot to remove any residual ticks and labels
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img00e3b1c2c62941279b634310d4796cc4">
#   <div class="anim-controls">
#     <input id="_anim_slider00e3b1c2c62941279b634310d4796cc4" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim00e3b1c2c62941279b634310d4796cc4.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim00e3b1c2c62941279b634310d4796cc4.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim00e3b1c2c62941279b634310d4796cc4.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim00e3b1c2c62941279b634310d4796cc4.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim00e3b1c2c62941279b634310d4796cc4.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim00e3b1c2c62941279b634310d4796cc4.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim00e3b1c2c62941279b634310d4796cc4.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim00e3b1c2c62941279b634310d4796cc4.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim00e3b1c2c62941279b634310d4796cc4.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim00e3b1c2c62941279b634310d4796cc4.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select00e3b1c2c62941279b634310d4796cc4"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_00e3b1c2c62941279b634310d4796cc4"
#              >
#       <label for="_anim_radio1_00e3b1c2c62941279b634310d4796cc4">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_00e3b1c2c62941279b634310d4796cc4"
#              checked>
#       <label for="_anim_radio2_00e3b1c2c62941279b634310d4796cc4">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_00e3b1c2c62941279b634310d4796cc4"
#              >
#       <label for="_anim_radio3_00e3b1c2c62941279b634310d4796cc4">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img00e3b1c2c62941279b634310d4796cc4";
#     var slider_id = "_anim_slider00e3b1c2c62941279b634310d4796cc4";
#     var loop_select_id = "_anim_loop_select00e3b1c2c62941279b634310d4796cc4";
#     var frames = new Array(41);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/MnkTPAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %% [markdown]
# ## 4. Compute Taylor videos on skeleton sequences

# %%
import os

# Directory path
directory = '/Users/leiwang/Desktop/skeleton'

# Loop through files in the directory
for filename in os.listdir(directory):
    # Check if the file ends with '.mat'
    if filename.endswith('.mat'):
        # Full path of the file
        filepath = os.path.join(directory, filename)
        # Process the file or perform operations as needed
        taylorskeleton = taylor_video(filepath, 1, 4)
        # New filename with 'taylor' added before '.mat'
        new_filename = filename.replace('.mat', 'taylor.mat')
        new_filepath = os.path.join(directory, new_filename)
        # print(new_filepath)
        print(f'Processing file: {filepath}')
        # Add your code here to work with the file
        taylorskeleton_array = taylorskeleton.double().numpy()

        # Save the NumPy array to a MATLAB file with key 'skeletonsequence'
        io.savemat(new_filepath, {'skeletonsequence': taylorskeleton_array}, appendmat=False, format='5')
# Out:
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s02_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s03_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s04_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s09_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s05_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s10_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s10_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s05_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s08_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s06_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s10_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s09_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s05_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s08_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s08_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s07_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s06_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s02_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s01_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s03_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s02_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s04_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s05_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s10_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s07_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s02_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s03_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s01_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s01_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s07_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s09_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s03_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s02_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s03_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s04_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s06_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s07_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s08_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s09_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s03_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s04_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s02_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s01_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s02_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s07_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s10_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s06_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s05_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s04_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s06_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s04_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s05_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s10_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s07_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s01_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s03_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s01_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s07_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s09_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s08_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s09_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s07_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s06_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s02_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s03_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s02_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s08_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s08_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s05_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s09_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s10_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s08_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s05_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s10_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s07_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s06_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s10_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s05_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s09_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s04_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s01_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s03_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s02_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s01_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s08_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s09_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s03_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s01_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s08_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s02_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s01_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s05_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s10_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s10_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s06_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s05_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s09_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s02_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s10_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s04_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s03_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s04_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s01_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s04_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s01_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s06_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s03_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s07_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s10_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a06_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s05_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a16_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s10_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s08_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a01_s07_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a08_s06_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s05_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s01_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s09_e01_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a15_s09_e03_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a10_s03_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s01_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a14_s08_e02_skeleton3D.txtssqtaylor.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s02_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a03_s07_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s08_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a19_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s06_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a17_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s02_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a04_s07_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a09_s03_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a18_s04_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s05_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a07_s09_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a12_s08_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s10_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a11_s06_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a05_s09_e02_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a02_s02_e03_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a13_s05_e01_skeleton3D.txtssq.mat
# Processing file: /Users/leiwang/Desktop/skeleton/a20_s01_e02_skeleton3D.txtssq.mat
